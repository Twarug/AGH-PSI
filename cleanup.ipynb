# %%
import pandas as pd
import ast
import json
import os

# %%
df = pd.read_csv("dataset/movies.csv", usecols=['genres','original_language', 'original_title', 'production_companies', 'production_countries', 'release_date', 'runtime', 'vote_average', 'vote_count'])

print(df.shape)
df = df.dropna()
print(df.shape)

df
# Out:
# (45466, 9)
# (45119, 9)
#                                                   genres original_language  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...                en
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...                en
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
# 4                         [{'id': 35, 'name': 'Comedy'}]                en
# ...                                                  ...               ...
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...                en
# 45462                      [{'id': 18, 'name': 'Drama'}]                tl
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...                en
# 45464                                                 []                en
# 45465                                                 []                en
#
#                     original_title  \
# ...

# %%
def extract_field(json, field):
    try:
        list_string = ast.literal_eval(json)

        if not isinstance(list_string, list):
            return ""
        
        names=[item.get(field) for item in list_string if isinstance(item, dict) and item.get(field)]

        return ", ".join(names)
    except (SyntaxError, ValueError):
        return ""

# %%
df['genres'] = df['genres'].apply(lambda x: extract_field(x, 'name'))
df['production_companies'] = df['production_companies'].apply(lambda x: extract_field(x, 'name'))
df['production_countries'] = df['production_countries'].apply(lambda x: extract_field(x, 'name'))
df
# Out:
#                            genres original_language  \
# 0       Animation, Comedy, Family                en
# 1      Adventure, Fantasy, Family                en
# 2                 Romance, Comedy                en
# 3          Comedy, Drama, Romance                en
# 4                          Comedy                en
# ...                           ...               ...
# 45460      Drama, Action, Romance                en
# 45462                       Drama                tl
# 45463     Action, Drama, Thriller                en
# 45464                                            en
# 45465                                            en
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45460                   Robin Hood
# 45462          Siglo ng Pagluluwal
# ...

# %%
output_directory = "dataset"
output_filename = "cleaned_movies_data.csv"
output_path = os.path.join(output_directory, output_filename)

try:
    df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"\nDataFrame został pomyślnie zapisany do pliku: {output_path}")
except Exception as e:
    print(f"\nWystąpił błąd podczas zapisywania pliku CSV: {e}")
# Out:
# DataFrame został pomyślnie zapisany do pliku: dataset\cleaned_movies_data.csv
